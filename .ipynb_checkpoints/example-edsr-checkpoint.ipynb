# %% [markdown]
# # EDSR

# %%
import os
import matplotlib.pyplot as plt

from data import DIV2K
from model.edsr import edsr
from train import EdsrTrainer
from tensorflow.python.keras import backend as K
import numpy as np
import tensorflow as tf
from model import resolve_single
from utils import load_image, plot_sample
import cv2
import numpy as np
import tensorflow as tf
# %matplotlib inline

# %%
# Number of residual blocks
depth = 8

# Super-resolution factor
scale = 1

# Downgrade operator
downgrade = 'bicubic'

# %%
# Location of model weights (needed for demo)
weights_dir = f'weights/edsr-{depth}-x{scale}'
weights_file = os.path.join(weights_dir, 'weights.h5')

os.makedirs(weights_dir, exist_ok=True)

# %%
model=edsr(scale=scale, num_res_blocks=depth)
dot_img_file = 'model_3.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %% [markdown]
# ## Datasets
#
# You don't need to download the DIV2K dataset as the required parts are automatically downloaded by the `DIV2K` class. By default, DIV2K images are stored in folder `.div2k` in the project's root directory.

# %%
div2k_train = DIV2K(scale=scale, subset='train', downgrade=downgrade)
div2k_valid = DIV2K(scale=scale, subset='valid', downgrade=downgrade)

# %%
train_ds = div2k_train.dataset(batch_size=1, random_transform=True) #4
valid_ds = div2k_valid.dataset(batch_size=1, random_transform=False, repeat_count=1)
# Out:
# Caching decoded images in .div2k/caches\DIV2K_train_LR_bicubic.cache ...
# Cached decoded images in .div2k/caches\DIV2K_train_LR_bicubic.cache.
# Caching decoded images in .div2k/caches\DIV2K_trainrgb_LR_bicubic.cache ...
# Cached decoded images in .div2k/caches\DIV2K_trainrgb_LR_bicubic.cache.
# Caching decoded images in .div2k/caches\DIV2K_train_HR.cache ...
# Cached decoded images in .div2k/caches\DIV2K_train_HR.cache.
# Caching decoded images in .div2k/caches\DIV2K_trainrgb_HR.cache ...
# Cached decoded images in .div2k/caches\DIV2K_trainrgb_HR.cache.
# <ZipDataset shapes: (((None, None, 1), (None, None, 3)), ((None, None, 1), (None, None, 3))), types: ((tf.uint16, tf.uint16), (tf.uint16, tf.uint16))>
# Caching decoded images in .div2k/caches\DIV2K_valid_LR_bicubic.cache ...
# Cached decoded images in .div2k/caches\DIV2K_valid_LR_bicubic.cache.
# Caching decoded images in .div2k/caches\DIV2K_validrgb_LR_bicubic.cache ...
# Cached decoded images in .div2k/caches\DIV2K_validrgb_LR_bicubic.cache.
# Caching decoded images in .div2k/caches\DIV2K_valid_HR.cache ...
# Cached decoded images in .div2k/caches\DIV2K_valid_HR.cache.
# Caching decoded images in .div2k/caches\DIV2K_validrgb_HR.cache ...
# Cached decoded images in .div2k/caches\DIV2K_validrgb_HR.cache.
# <ZipDataset shapes: (((None, None, 1), (None, None, 3)), ((None, None, 1), (None, None, 3))), types: ((tf.uint16, tf.uint16), (tf.uint16, tf.uint16))>

# %% [markdown]
# ## Training
#
# ### Pre-trained models
#
# If you want to skip training and directly run the demo below, download [weights-edsr-16-x4.tar.gz](https://drive.google.com/open?id=1xjyW_0dDS4jSTxKVZwtlkyfS4Oso-GUF) and extract the archive in the project's root directory. This will create a `weights/edsr-16-x4` directory containing the weights of the pre-trained model.

# %%
trainer = EdsrTrainer(model=edsr(scale=scale, num_res_blocks=depth), 
                      checkpoint_dir=f'.ckpt/edsr-{depth}-x{scale}')

# %%
# Train EDSR model for 300,000 steps and evaluate model
# every 1000 steps on the first 10 images of the DIV2K
# validation set. Save a checkpoint only if evaluation
# PSNR has improved.
trainer.train(train_ds,
              valid_ds.take(1),
              steps=1000, 
              evaluate_every=100, 
              save_best_only=True)
# Out:
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     925         "explicit_paddings", explicit_paddings, "data_format", data_format,
# --> 926         "dilations", dilations)
#     927       return _result
#
# _FallbackException: Expecting int64_t value for attr strides, got numpy.int32
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-9e76ae8d66ed> in <module>
#       7               steps=1000,
#       8               evaluate_every=100,
# ----> 9               save_best_only=True)
#
# E:\Anna\super-resolution-master\super-resolution-master\train.py in train(self, train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
#     199
#     200     def train(self, train_dataset, valid_dataset, steps=300000, evaluate_every=1000, save_best_only=True):
# --> 201         super().train(train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
#     202
#     203     def scale_invariant_loss(self, y_true, y_pred):
#
# E:\Anna\super-resolution-master\super-resolution-master\train.py in train(self, train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
#      62
#      63                 # Compute PSNR on validation dataset
# ---> 64                 psnr_value = self.evaluate(valid_dataset)
#      65
#      66                 duration = time.perf_counter() - self.now
#
# E:\Anna\super-resolution-master\super-resolution-master\train.py in evaluate(self, dataset)
#      93
#      94     def evaluate(self, dataset):
# ---> 95         return evaluate(self.checkpoint.model, dataset)
#      96
#      97     def restore(self):
#
# E:\Anna\super-resolution-master\super-resolution-master\model\common.py in evaluate(model, dataset)
#      25     psnr_values = []
#      26     for lr, hr in dataset:
# ---> 27         sr = resolve(model, lr)
#      28         psnr_value = psnr(hr, sr)[0]
#      29         #psnr_value = scale_invariant_error(hr, sr)[0]
#
# E:\Anna\super-resolution-master\super-resolution-master\model\common.py in resolve(model, lr_batch)
#      14 def resolve(model, lr_batch):
#      15     lr_batch = tf.cast(lr_batch, tf.uint16)
# ---> 16     sr_batch = model(lr_batch)
#      17     #sr_batch = tf.clip_by_value(sr_batch, 0, 255)
#      18     #sr_batch = tf.clip_by_value(sr_batch, 0, 2000)
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\keras\engine\network.py in call(self, inputs, training, mask)
#     715     return self._run_internal_graph(
#     716         inputs, training=training, mask=mask,
# --> 717         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     718
#     719   def compute_output_shape(self, input_shape):
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\keras\engine\network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     889
#     890           # Compute outputs.
# --> 891           output_tensors = layer(computed_tensors, **kwargs)
#     892
#     893           # Update tensor_dict.
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\keras\layers\convolutional.py in call(self, inputs)
#     207       inputs = array_ops.pad(inputs, self._compute_causal_padding())
#     208
# --> 209     outputs = self._convolution_op(inputs, self.kernel)
#     210
#     211     if self.use_bias:
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in __call__(self, inp, filter)
#    1133           call_from_convolution=False)
#    1134     else:
# -> 1135       return self.conv_op(inp, filter)
#    1136     # copybara:strip_end
#    1137     # copybara:insert return self.conv_op(inp, filter)
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in __call__(self, inp, filter)
#     638
#     639   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 640     return self.call(inp, filter)
#     641
#     642
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in __call__(self, inp, filter)
#     237         padding=self.padding,
#     238         data_format=self.data_format,
# --> 239         name=self.name)
#     240
#     241
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name, filters)
#    2009                            data_format=data_format,
#    2010                            dilations=dilations,
# -> 2011                            name=name)
#    2012
#    2013
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     931             input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#     932             padding=padding, explicit_paddings=explicit_paddings,
# --> 933             data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#     934       except _core._SymbolicException:
#     935         pass  # Add nodes to the TensorFlow graph.
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1013         "'conv2d' Op, not %r." % dilations)
#    1014   dilations = [_execute.make_int(_i, "dilations") for _i in dilations]
# -> 1015   _attr_T, _inputs_T = _execute.args_to_matching_eager([input, filter], ctx)
#    1016   (input, filter) = _inputs_T
#    1017   _inputs_flat = [input, filter]
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\eager\execute.py in args_to_matching_eager(l, ctx, default_dtype)
#     265         dtype = ret[-1].dtype
#     266   else:
# --> 267     ret = [ops.convert_to_tensor(t, dtype, ctx=ctx) for t in l]
#     268
#     269   # TODO(slebedev): consider removing this as it leaks a Keras concept.
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\eager\execute.py in <listcomp>(.0)
#     265         dtype = ret[-1].dtype
#     266   else:
# --> 267     ret = [ops.convert_to_tensor(t, dtype, ctx=ctx) for t in l]
#     268
#     269   # TODO(slebedev): consider removing this as it leaks a Keras concept.
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1312
#    1313     if ret is None:
# -> 1314       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1315
#    1316     if ret is NotImplemented:
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in _dense_var_to_tensor(var, dtype, name, as_ref)
#    1792
#    1793 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 1794   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)  # pylint: disable=protected-access
#    1795
#    1796
#
# ~\AppData\Local\conda\conda\envs\sisr\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py in _dense_var_to_tensor(***failed resolving arguments***)
#    1213       raise ValueError(
#    1214           "Incompatible type conversion requested to type {!r} for variable "
# -> 1215           "of type {!r}".format(dtype.name, self.dtype.name))
#    1216     if as_ref:
#    1217       return self.read_value().op.inputs[0]
#
# ValueError: Incompatible type conversion requested to type 'uint16' for variable of type 'float32'

# %%
lr = np.array(cv2.imread('demo/2lr.png', cv2.IMREAD_ANYDEPTH))

# %%
# Restore from checkpoint with highest PSNR
trainer.restore()

# %%
# Evaluate model on full validation set
psnrv = trainer.evaluate(valid_ds)
print(f'PSNR = {psnrv.numpy():3f}')

# %%
# Save weights to separate location (needed for demo)
trainer.model.save_weights(weights_file)

# %% [markdown]
# ## Demo

# %%
model = edsr(scale=scale, num_res_blocks=depth)
model.load_weights(weights_file)

# %%
def plot_diff(lr, sr):
    plt.figure(figsize=(30, 10))
    diff = cv2.subtract(np.array(lr,np.float32),np.array(sr,np.float32))
    #diff_lr_hr = np.clip(diff,0,1000)
    images = [lr, sr, diff]
    titles = ['LR','HR','Difference']
      
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        heatmap = plt.pcolor(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
        plt.colorbar(heatmap)

# %%
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 100.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

def compute_bins(lr,hr, bins):
    for k in range(len(bins)+1):
        if k==0:
            st = 0
            end = bins[k]
        elif k==len(bins):
            st = bins[k-1]
            end = 9000
        else:
            st = bins[k-1]
            end = bins[k]
        mask = np.zeros_like(lr)
        mask1 = np.ma.masked_outside(lr,st,end)
        mask2 = np.ma.masked_outside(hr,st,end)
        #ssim
        (score, diff) = structural_similarity(mask1, mask2, data_range=100., full=True)     
        print("SSIM for range ",st,"-",end,":",round(score,5))
        #pnsr
        print("PNSR for range ",st,"-",end,":",round(PSNR(mask1, mask2),5))
        
        diff = (diff * 255).astype("uint8")
        print(np.max(diff), np.min(diff))
        plot_sample(mask1, mask2)
        print("-----------------------------------")

# %%
lr = np.array(cv2.imread('demo/lr1.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/lrrgb1.png'))
hr = np.array(cv2.imread('demo/hr1.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/hrrgb1.png'))

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
cv2.imwrite('demo/1_res.png',depth)    
        

bins = [400]
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
lr = np.array(cv2.imread('demo/2lr.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb2lr.png'))
hr = np.array(cv2.imread('demo/2hr.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb2hr.png'))

(score, diff) = structural_similarity(lr, hr, data_range=9000., full=True)  
print(np.max(diff),np.min(diff))
k = diff
plt.imshow(k)

# %%
lr = np.array(cv2.imread('demo/2_res.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb2lr.png'))
hr = np.array(cv2.imread('demo/2hr.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb2hr.png'))

(score, diff) = structural_similarity(lr, hr, data_range=300., full=True)  
print(np.max(1-(1-diff*0.5)),np.min(1-(1-diff*0.5)))
k = 1-(1-diff*0.5)
plt.imshow(k)

# %%
lr = np.array(cv2.imread('demo/2lr.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb2lr.png'))
hr = np.array(cv2.imread('demo/2hr.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb2hr.png'))

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
cv2.imwrite('demo/2_res.png',depth)    
        

bins = [400]
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
from math import log10, sqrt 
import cv2 
import numpy as np 
from skimage.metrics import structural_similarity 
import argparse
import imutils
import cv2

downsample_rate = 1

lr = np.array(cv2.imread('demo/lr358.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb358lr.png'))
hr = np.array(cv2.imread('demo/hr358.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb358hr.png'))

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)

plot_sample(hr[:,:], depth)
cv2.imwrite('demo/358_res.png',depth)    

bins = [800,900] 
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score,5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr),5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
from math import log10, sqrt 
import cv2 
import numpy as np 
from skimage.metrics import structural_similarity 
import argparse
import imutils
import cv2
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

def compute_bins(lr,hr):
    bins = [400,450]    
    for k in range(len(bins)+1):
        if k==0:
            st = 0
            end = bins[k]
        elif k==len(bins):
            st = bins[k-1]
            end = 10000
        else:
            st = bins[k-1]
            end = bins[k]
        mask = np.zeros_like(lr)
        mask1 = np.ma.masked_outside(lr,st,end)
        mask2 = np.ma.masked_outside(hr,st,end)
        #ssim
        (score, diff) = structural_similarity(mask1, mask2, full=True)
        diff = (diff * 255).astype("uint8")      
        print("SSIM for range ",st,"-",end,":",round(score,5))
        #pnsr
        print("PNSR for range ",st,"-",end,":",round(PSNR(mask1, mask2),5))
        plot_sample(mask1, mask2)
        print("-----------------------------------")
        

        


print("------predicted----------")
compute_bins(depth, hr)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score,5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr),5)))

print("")
print("------original----------")
compute_bins(lr, hr)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
from model import resolve_single
from utils import load_image, plot_sample
import cv2
import tensorflow as tf
import numpy as np

def plot_diff(lr, sr):
    plt.figure(figsize=(30, 10))
    diff = cv2.subtract(np.array(lr,np.float32),np.array(sr,np.float32))
    diff_lr_hr = abs(diff)
    images = [lr, sr, diff_lr_hr]
    titles = ['LR','HR','Difference']
    
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        heatmap = plt.pcolor(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
        plt.colorbar(heatmap)

plot_diff(lr,hr)

# %%
from model import resolve_single
from utils import load_image, plot_sample
import cv2
import numpy as np
import tensorflow as tf

def resolve_and_plot(lr_image_path):
    print(lr_image_path)
    lr = load_image(lr_image_path)
    lr = np.clip(lr, 0, 1000)

    lr = np.expand_dims(lr,2)      
    lr = lr[0::2,0::2]
    sr = resolve_single(model, lr)
    
    sr_array = np.array(sr[:,:,0])
    depth = sr_array.astype(np.uint16)
    
    plot_sample(lr[:,:,0], depth)
    cv2.imwrite(lr_image_path.split(".")[0]+"_result.png",depth)

# %%
from model import resolve_single
from utils import load_image, plot_sample
import cv2
import tensorflow as tf
import numpy as np

def plot_diff(lr, sr):
    plt.figure(figsize=(30, 10))
    diff = cv2.subtract(np.array(lr,np.float32),np.array(sr,np.float32))
    #diff_lr_hr = np.clip(diff,0,1000)
    images = [lr, sr, diff]
    titles = ['LR','HR','Difference']
    
    
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        heatmap = plt.pcolor(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
        plt.colorbar(heatmap)

# %%
sr = np.array(cv2.imread('demo/0_res.png', cv2.IMREAD_ANYDEPTH))
sr = np.clip(lr,0,1000)
hr = np.array(cv2.imread('demo/hr0 (2).png', cv2.IMREAD_ANYDEPTH))
hr = np.clip(hr,0,1000)

plot_diff(sr,hr)

# %%
(score, diff) = compare_ssim(sr, hr, full=True)
diff = (diff * 255).astype("uint8")

# 6. You can print only the score if you want
print("SSIM: {}".format(score))
