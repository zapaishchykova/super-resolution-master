# %% [markdown]
# # EDSR

# %%
import os
import matplotlib.pyplot as plt

from data import DIV2K
from model.edsr import edsr_a
from train import EdsrTrainer
from tensorflow.python.keras import backend as K
import numpy as np
import tensorflow as tf
from model import resolve_single
from utils import load_image, plot_sample
import cv2
import numpy as np
import tensorflow as tf
# %matplotlib inline

# %%
# Number of residual blocks
depth = 8

# Super-resolution factor
scale = 1

# Downgrade operator
downgrade = 'bicubic'

# %%
# Location of model weights (needed for demo)
weights_dir = f'weights/edsr-{depth}-x{scale}'
weights_file = os.path.join(weights_dir, 'weights.h5')

os.makedirs(weights_dir, exist_ok=True)

# %%
model=edsr_a(scale=scale, num_res_blocks=depth)
dot_img_file = 'model_3.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
model.summary(150)
# Out:
# Model: "model"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_1 (InputLayer)                             [(None, None, None, 2)]          0
# ______________________________________________________________________________________________________________________________________________________
# tf_op_layer_split (TensorFlowOpLayer)            [(None, None, None, 1), (None, N 0                 input_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# lambda (Lambda)                                  (None, None, None, 1)            0                 tf_op_layer_split[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization (WeightNormalization)       (None, None, None, 32)           193               lambda[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_1 (WeightNormalization)     (None, None, None, 128)          37121             weight_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_2 (WeightNormalization)     (None, None, None, 32)           36929             weight_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add (Add)                                        (None, None, None, 32)           0                 weight_normalization[0][0]
#                                                                                                     weight_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_3 (WeightNormalization)     (None, None, None, 128)          37121             add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_4 (WeightNormalization)     (None, None, None, 32)           36929             weight_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_1 (Add)                                      (None, None, None, 32)           0                 add[0][0]
#                                                                                                     weight_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_5 (WeightNormalization)     (None, None, None, 128)          37121             add_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_6 (WeightNormalization)     (None, None, None, 32)           36929             weight_normalization_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_2 (Add)                                      (None, None, None, 32)           0                 add_1[0][0]
#                                                                                                     weight_normalization_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_7 (WeightNormalization)     (None, None, None, 128)          37121             add_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_8 (WeightNormalization)     (None, None, None, 32)           36929             weight_normalization_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_3 (Add)                                      (None, None, None, 32)           0                 add_2[0][0]
#                                                                                                     weight_normalization_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_9 (WeightNormalization)     (None, None, None, 128)          37121             add_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_10 (WeightNormalization)    (None, None, None, 32)           36929             weight_normalization_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_4 (Add)                                      (None, None, None, 32)           0                 add_3[0][0]
#                                                                                                     weight_normalization_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_11 (WeightNormalization)    (None, None, None, 128)          37121             add_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_12 (WeightNormalization)    (None, None, None, 32)           36929             weight_normalization_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_5 (Add)                                      (None, None, None, 32)           0                 add_4[0][0]
#                                                                                                     weight_normalization_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_13 (WeightNormalization)    (None, None, None, 128)          37121             add_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_14 (WeightNormalization)    (None, None, None, 32)           36929             weight_normalization_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_6 (Add)                                      (None, None, None, 32)           0                 add_5[0][0]
#                                                                                                     weight_normalization_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_15 (WeightNormalization)    (None, None, None, 128)          37121             add_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_16 (WeightNormalization)    (None, None, None, 32)           36929             weight_normalization_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_7 (Add)                                      (None, None, None, 32)           0                 add_6[0][0]
#                                                                                                     weight_normalization_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_17 (WeightNormalization)    (None, None, None, 1)            291               add_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_19 (WeightNormalization)    (None, None, None, 3)            82                lambda[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_18 (WeightNormalization)    (None, None, None, 3)            34                weight_normalization_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# weight_normalization_20 (WeightNormalization)    (None, None, None, 1)            78                weight_normalization_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_8 (Add)                                      (None, None, None, 3)            0                 weight_normalization_18[0][0]
#                                                                                                     weight_normalization_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# add_9 (Add)                                      (None, None, None, 3)            0                 add_8[0][0]
#                                                                                                     tf_op_layer_split[0][0]
# ______________________________________________________________________________________________________________________________________________________
# lambda_1 (Lambda)                                (None, None, None, 3)            0                 add_9[0][0]
# ======================================================================================================================================================
# Total params: 593,078
# Trainable params: 593,057
# Non-trainable params: 21
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Datasets
#
# You don't need to download the DIV2K dataset as the required parts are automatically downloaded by the `DIV2K` class. By default, DIV2K images are stored in folder `.div2k` in the project's root directory.

# %%
div2k_train = DIV2K(scale=scale, subset='train', downgrade=downgrade)
div2k_valid = DIV2K(scale=scale, subset='valid', downgrade=downgrade)

# %%
train_ds = div2k_train.dataset(batch_size=1, random_transform=True) #4
valid_ds = div2k_valid.dataset(batch_size=1, random_transform=False, repeat_count=1)

# %% [markdown]
# ## Training
#
# ### Pre-trained models
#
# If you want to skip training and directly run the demo below, download [weights-edsr-16-x4.tar.gz](https://drive.google.com/open?id=1xjyW_0dDS4jSTxKVZwtlkyfS4Oso-GUF) and extract the archive in the project's root directory. This will create a `weights/edsr-16-x4` directory containing the weights of the pre-trained model.

# %%
trainer = EdsrTrainer(model=edsr_a(scale=scale, num_res_blocks=depth), 
                      checkpoint_dir=f'.ckpt/edsr-{depth}-x{scale}')

# %% [markdown]
# for element in train_ds:
#     print(element)

# %%
# Train EDSR model for 300,000 steps and evaluate model
# every 1000 steps on the first 10 images of the DIV2K
# validation set. Save a checkpoint only if evaluation
# PSNR has improved.
trainer.train(train_ds,
              valid_ds.take(1),
              steps=1000, 
              evaluate_every=100, 
              save_best_only=True)

# %% [markdown]
# # Restore from checkpoint with highest PSNR
# trainer.restore()

# %%
# Evaluate model on full validation set
psnrv = trainer.evaluate(valid_ds)
print(f'PSNR = {psnrv.numpy():3f}')

# %%
# Save weights to separate location (needed for demo)
trainer.model.save_weights(weights_file)

# %% [markdown]
# ## Demo

# %%
model = edsr(scale=scale, num_res_blocks=depth)
model.load_weights(weights_file)

# %%
def plot_diff(lr, sr):
    plt.figure(figsize=(30, 10))
    diff = cv2.subtract(np.array(lr,np.float32),np.array(sr,np.float32))
    #diff_lr_hr = np.clip(diff,0,1000)
    images = [lr, sr, diff]
    titles = ['LR','HR','Difference']
      
    for i, (img, title) in enumerate(zip(images, titles)):
        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        heatmap = plt.pcolor(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
        plt.colorbar(heatmap)

# %%
from math import log10, sqrt 
import cv2 
import numpy as np 
from skimage.metrics import structural_similarity 
import argparse
import imutils
import cv2

downsample_rate = 1
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal . 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 2500.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

def compute_bins(lr,hr, bins):
    for k in range(len(bins)+1):
        if k==0:
            st = 0
            end = bins[k]
        elif k==len(bins):
            st = bins[k-1]
            end = 9000
        else:
            st = bins[k-1]
            end = bins[k]
        mask = np.zeros_like(lr)
        mask1 = np.ma.masked_outside(lr,st,end)
        mask2 = np.ma.masked_outside(hr,st,end)
        #ssim
        (score, diff) = structural_similarity(mask1, mask2, full=True)     
        print("SSIM for range ",st,"-",end,":",round(score,5))
        #pnsr
        print("PNSR for range ",st,"-",end,":",round(PSNR(mask1, mask2),5))
        
        diff = (diff * 255).astype("uint8")
        print(np.max(diff), np.min(diff))
        plot_sample(mask1, mask2)
        print("-----------------------------------")

# %%
lr = np.array(cv2.imread('demo/depth_lr.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/col_lr.png',cv2.IMREAD_GRAYSCALE))
hr = np.array(cv2.imread('demo/depth.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/col.png',cv2.IMREAD_GRAYSCALE))

(score, diff) = structural_similarity(lr, hr, data_range=2500., full=True)  
print(np.max(diff),np.min(diff))
k = diff
plt.imshow(k)

lr = np.expand_dims(lr,2)  
lr_rgb = np.expand_dims(lr_rgb,2)  

lrmerged = np.concatenate([lr, lr_rgb], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
print(np.shape(depth),np.shape(hr))
cv2.imwrite('demo/0_res.png',depth)    
        

bins = [700,1500]
print("------predicted----------")

print(np.shape(depth),np.shape(hr))
compute_bins(depth, hr, bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
lr = lr[:,:,0]
print(np.shape(lr),np.shape(hr))
compute_bins(lr, hr, bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
lr = np.array(cv2.imread('demo/0.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb0.png'))
hr = np.array(cv2.imread('demo/hr0.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb0.png'))

(score, diff) = structural_similarity(lr, hr, data_range=1000., full=True)  
print(np.max(diff),np.min(diff))
k = diff
plt.imshow(k)

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
cv2.imwrite('demo/0_res.png',depth)    
        

bins = [700]
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
from math import log10, sqrt 
import cv2 
import numpy as np 
from skimage.metrics import structural_similarity 
import argparse
import imutils
import cv2

downsample_rate = 1
lr = np.array(cv2.imread('demo/95.png', cv2.IMREAD_ANYDEPTH)) 
lr_rgb = np.array(cv2.imread('demo/rgb95.png'))
hr = np.array(cv2.imread('demo/hr95.png', cv2.IMREAD_ANYDEPTH)) 
#hr_rgb = np.array(cv2.imread('demo/hrrgb1.png'))

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate] 
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
cv2.imwrite('demo/95_res.png',depth)    
        

bins = [100]
print("------predicted----------")

compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
def norm(img):
    mean = np.mean(img, axis=(0), keepdims=True)
    std = np.std(img, axis=(0), keepdims=True)
    standardized_images_out = (img - mean) / std
    return standardized_images_out

# %%
lr = np.array(cv2.imread('demo/lr0.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb0.png'))
hr = np.array(cv2.imread('demo/0.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb0.png'))

(score, diff) = structural_similarity(lr, hr, data_range=5000., full=True)  
print(np.max(diff),np.min(diff))
k = diff
plt.imshow(k)

# %%
#lr = np.array(cv2.imread('demo/2lr.png', cv2.IMREAD_ANYDEPTH))
#lr_rgb = np.array(cv2.imread('demo/rgb2lr.png'))
#hr = np.array(cv2.imread('demo/2hr.png', cv2.IMREAD_ANYDEPTH))
#hr_rgb = np.array(cv2.imread('demo/rgb2hr.png'))
lr = np.array(cv2.imread('demo/lr0.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb0.png'))
hr = np.array(cv2.imread('demo/0.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb0.png'))

(score, diff) = structural_similarity(lr, hr, data_range=5000., full=True)  
print(np.max(diff),np.min(diff))
k = diff
plt.imshow(k)

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)
cv2.imwrite('demo/2_res.png',depth)    
        

bins = [400]
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score, 5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr), 5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))

# %%
from math import log10, sqrt 
import cv2 
import numpy as np 
from skimage.metrics import structural_similarity 
import argparse
import imutils
import cv2

downsample_rate = 1

lr = np.array(cv2.imread('demo/lr358.png', cv2.IMREAD_ANYDEPTH))
lr_rgb = np.array(cv2.imread('demo/rgb358lr.png'))
hr = np.array(cv2.imread('demo/hr358.png', cv2.IMREAD_ANYDEPTH))
hr_rgb = np.array(cv2.imread('demo/rgb358hr.png'))

lr_downsampled = lr[0::downsample_rate, 0::downsample_rate]
lr_downsampled = np.expand_dims(lr_downsampled,2)  
lr_rgb_downsampled = lr_rgb[0::downsample_rate, 0::downsample_rate]
 
lrmerged = np.concatenate([lr_downsampled, lr_rgb_downsampled], 2)    
sr = resolve_single(model, lrmerged)

sr_array = np.array(sr[:,:,0])
depth = sr_array.astype(np.uint16)

plot_sample(hr[:,:], depth)
cv2.imwrite('demo/358_res.png',depth)    

bins = [800,900] 
print("------predicted----------")
compute_bins(depth, hr,bins)
(score, diff) = structural_similarity(depth, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM predicted whole image: {}".format(round(score,5)))
print("PNSR predicted whole image: {}".format(round(PSNR(depth, hr),5)))

print("")
print("------original----------")
compute_bins(lr, hr,bins)
(score, diff) = structural_similarity(lr, hr, full=True)
diff = (diff * 255).astype("uint8")
print("SSIM original whole image: {}".format(round(score,5)))
print("PNSR original whole image:  {}".format(round(PSNR(lr, hr),5)))
